# %%
# !pip install -U scikit-fuzzy
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import matplotlib.pyplot as plt
# Out:
# Requirement already up-to-date: scikit-fuzzy in /usr/local/lib/python3.6/dist-packages (0.4.1)
# ...

# %%
walk_to_workplace = ctrl.Antecedent(np.arange(1, 3, 1), 'qualwalk_to_workplaceity')
smoking = ctrl.Antecedent(np.arange(1, 6, 1), 'smoking')
drinking_alchohol = ctrl.Antecedent(np.arange(1, 6, 1), 'drinking_alchohol')
hours_sit = ctrl.Antecedent(np.arange(1, 6, 1), 'hours_sit')
sit_straight = ctrl.Antecedent(np.arange(1, 3, 1), 'sit_straight')
cushioned_chair_to_sit = ctrl.Antecedent(np.arange(1, 3, 1), 'cushioned_chair_to_sit')

sit_in_front_of_computer = ctrl.Antecedent(np.arange(1, 6, 1), 'sit_in_front_of_computer')
walk_after_lunch_dinner = ctrl.Antecedent(np.arange(1, 3, 1), 'walk_after_lunch_dinner')
exercise = ctrl.Antecedent(np.arange(1, 5, 1), 'exercise')

junk_food = ctrl.Antecedent(np.arange(1, 5, 1), 'sit_in_front_of_computer')
eight_hours_sleep = ctrl.Antecedent(np.arange(1, 3, 1), 'walk_after_lunch_dinner')
hours_spend_on_social_media = ctrl.Antecedent(np.arange(1, 6, 1), 'exercise')

stress_personal_life_work_life = ctrl.Antecedent(np.arange(1, 4, 1), 'stress_personal_life_work_life')
sit_in_traffic_jam = ctrl.Antecedent(np.arange(1, 6, 1), 'sit_in_traffic_jam')
use_headphones_or_earphones_constantly = ctrl.Antecedent(np.arange(1, 6, 1), 'use_headphones_or_earphones_constantly')

headache = ctrl.Antecedent(np.arange(1, 5, 1), 'headache')
depression = ctrl.Antecedent(np.arange(1, 3, 1), 'depression')
tiredness = ctrl.Antecedent(np.arange(1, 6, 1), 'tiredness')

# %%
#ouput
#same for output as done above
mental_illness = ctrl.Consequent(np.arange(0, 2, 1), 'Mental illness')

back_pain = ctrl.Consequent(np.arange(0, 2, 1), 'Back Pain')

stroke = ctrl.Consequent(np.arange(0, 2, 1), 'Stroke')

atherosclerosis = ctrl.Consequent(np.arange(0, 2, 1), 'atherosclerosis')

Obesity = ctrl.Consequent(np.arange(0, 2, 1), 'Obesity')

Heart_Disease = ctrl.Consequent(np.arange(0, 2, 1), 'Heart Disease')

High_Blood_Pressure = ctrl.Consequent(np.arange(0, 2, 1), 'High Blood Pressure')

Type_II_Diabetes = ctrl.Consequent(np.arange(0, 2, 1), 'Type-II Diabetes')

Chronic_Obstructive_Pulmonary_Disease=ctrl.Consequent(np.arange(0, 2, 1), 'Chronic obstructive pulmonary disease')

Chronic_Renal_Failure=ctrl.Consequent(np.arange(0, 2, 1), 'Chronic renal failure')

Osteoporosis=ctrl.Consequent(np.arange(0, 2, 1), 'Osteoporosis')

Swimmer_s_ear=ctrl.Consequent(np.arange(0, 2, 1), "Swimmer's ear")

Nephritis=ctrl.Consequent(np.arange(0, 2, 1), 'Nephritis')

Eye_Pain=ctrl.Consequent(np.arange(0, 2, 1), 'Eye Pain')

# %%
walk_to_workplace['yes'] = fuzz.trimf(walk_to_workplace.universe, [0, 0, 1])
walk_to_workplace['no'] = fuzz.trimf(walk_to_workplace.universe, [0, 1, 2])


smoking['Daily'] = fuzz.trimf(smoking.universe, [0, 0, 1])
smoking['3-4 Days in a week'] = fuzz.trimf(smoking.universe, [0, 1, 2])
smoking['Occasionally'] = fuzz.trimf(smoking.universe, [1, 2, 3])
smoking['No, I do not smoke'] = fuzz.trimf(smoking.universe, [2, 3, 4])


drinking_alchohol['Daily'] = fuzz.trimf(drinking_alchohol.universe, [0, 0, 1])
drinking_alchohol['3-4 Days in a week'] = fuzz.trimf(drinking_alchohol.universe, [0, 1, 2])
drinking_alchohol['Occasionally'] = fuzz.trimf(drinking_alchohol.universe, [1, 2, 3])
drinking_alchohol['No, I do not smoke'] = fuzz.trimf(drinking_alchohol.universe, [2, 3, 4])

hours_sit['More than 10 hours'] = fuzz.trimf(hours_sit.universe, [0, 0, 1])
hours_sit['10 hours'] = fuzz.trimf(hours_sit.universe, [0, 1, 2])
hours_sit['9 hours'] = fuzz.trimf(hours_sit.universe, [1, 2, 3])
hours_sit['8 hours'] = fuzz.trimf(hours_sit.universe, [2, 3, 4])
hours_sit['less than 8 hours'] = fuzz.trimf(hours_sit.universe, [2, 3, 4])

sit_straight['yes'] = fuzz.trimf(sit_straight.universe, [0, 0, 1])
sit_straight['no'] = fuzz.trimf(sit_straight.universe, [0, 1, 2])

cushioned_chair_to_sit['yes'] = fuzz.trimf(cushioned_chair_to_sit.universe, [0, 0, 1])
cushioned_chair_to_sit['no'] = fuzz.trimf(cushioned_chair_to_sit.universe, [0, 1, 2])
# 
sit_in_front_of_computer['More than 12 hours'] = fuzz.trimf(sit_in_front_of_computer.universe, [0, 0, 1])
sit_in_front_of_computer['12 hours'] = fuzz.trimf(sit_in_front_of_computer.universe, [0, 1, 2])
sit_in_front_of_computer['8 hours'] = fuzz.trimf(sit_in_front_of_computer.universe, [1, 2, 3])
sit_in_front_of_computer['less than 8 hours'] = fuzz.trimf(sit_in_front_of_computer.universe, [2, 3, 4])
sit_in_front_of_computer['No, I do not sit'] = fuzz.trimf(sit_in_front_of_computer.universe, [2, 3, 4])

walk_after_lunch_dinner['yes'] = fuzz.trimf(walk_after_lunch_dinner.universe, [0, 0, 1])
walk_after_lunch_dinner['no'] = fuzz.trimf(walk_after_lunch_dinner.universe, [0, 1, 2])

exercise['No,I do not'] = fuzz.trimf(exercise.universe, [0, 0, 1])
exercise['sometimes'] = fuzz.trimf(exercise.universe, [0, 1, 2])
exercise['3-4 days in a week'] = fuzz.trimf(exercise.universe, [1, 2, 3])
exercise['Daily'] = fuzz.trimf(exercise.universe, [2, 3, 4])

junk_food['Daily'] = fuzz.trimf(junk_food.universe, [0, 0, 1])
junk_food['3-4 days in a week'] = fuzz.trimf(junk_food.universe, [0, 1, 2])
junk_food['Sometimes'] = fuzz.trimf(junk_food.universe, [1, 2, 3])
junk_food['No,I do not eat at all'] = fuzz.trimf(junk_food.universe, [2, 3, 4])

eight_hours_sleep['yes'] = fuzz.trimf(eight_hours_sleep.universe, [0, 0, 1])
eight_hours_sleep['no'] = fuzz.trimf(eight_hours_sleep.universe, [0, 1, 2])

hours_spend_on_social_media['More than 4 hours'] = fuzz.trimf(hours_spend_on_social_media.universe, [0, 0, 1])
hours_spend_on_social_media['3 to 4 hours'] = fuzz.trimf(hours_spend_on_social_media.universe, [0, 1, 2])
hours_spend_on_social_media['1 to 2 hours'] = fuzz.trimf(hours_spend_on_social_media.universe, [1, 2, 3])
hours_spend_on_social_media['Less than 1 hour'] = fuzz.trimf(hours_spend_on_social_media.universe, [2, 3, 4])


stress_personal_life_work_life['Yes,I do'] = fuzz.trimf(stress_personal_life_work_life.universe, [0, 0, 1])
stress_personal_life_work_life['Sometimes'] = fuzz.trimf(stress_personal_life_work_life.universe, [0, 1, 2])
stress_personal_life_work_life['No,I do not work'] = fuzz.trimf(stress_personal_life_work_life.universe, [1, 2, 3])

sit_in_traffic_jam['More than 2 hours'] = fuzz.trimf(sit_in_traffic_jam.universe, [0, 0, 1])
sit_in_traffic_jam['2 hours'] = fuzz.trimf(sit_in_traffic_jam.universe, [0, 1, 2])
sit_in_traffic_jam['1 hours'] = fuzz.trimf(sit_in_traffic_jam.universe, [1, 2, 3])
sit_in_traffic_jam['less than  hours'] = fuzz.trimf(sit_in_traffic_jam.universe, [2, 3, 4])
sit_in_traffic_jam['No, I do not sit'] = fuzz.trimf(sit_in_traffic_jam.universe, [2, 3, 4])

use_headphones_or_earphones_constantly['More than 2 hours'] = fuzz.trimf(use_headphones_or_earphones_constantly.universe, [0, 0, 1])
use_headphones_or_earphones_constantly['2 hours'] = fuzz.trimf(use_headphones_or_earphones_constantly.universe, [0, 1, 2])
use_headphones_or_earphones_constantly['1 hours'] = fuzz.trimf(use_headphones_or_earphones_constantly.universe, [1, 2, 3])
use_headphones_or_earphones_constantly['less than  hours'] = fuzz.trimf(use_headphones_or_earphones_constantly.universe, [2, 3, 4])
use_headphones_or_earphones_constantly['No, I do not sit'] = fuzz.trimf(use_headphones_or_earphones_constantly.universe, [2, 3, 4])



headache['Very Often'] = fuzz.trimf(headache.universe, [0, 0, 1])
headache['Sometimes'] = fuzz.trimf(headache.universe, [0, 1, 2])
headache['No,I do not'] = fuzz.trimf(headache.universe, [1, 2, 3])

depression['Very Often'] = fuzz.trimf(depression.universe, [0, 0, 1])
depression['Sometimes'] = fuzz.trimf(depression.universe, [0, 1, 2])
depression['No,I do not'] = fuzz.trimf(depression.universe, [1, 2, 3])

tiredness['Very Often'] = fuzz.trimf(tiredness.universe, [0, 0, 1])
tiredness['Sometimes'] = fuzz.trimf(tiredness.universe, [0, 1, 2])
tiredness['No,I do not'] = fuzz.trimf(tiredness.universe, [1, 2, 3])

# %%
#again a sample example
mental_illness["Yes"]=fuzz.trimf(mental_illness.universe, [0, 0, 1])
mental_illness["No"]=fuzz.trimf(mental_illness.universe, [0, 1, 1])

back_pain["Yes"]=fuzz.trimf(back_pain.universe, [0, 0, 1])
back_pain["No"]=fuzz.trimf(back_pain.universe, [0, 1, 1])

stroke["Yes"]=fuzz.trimf(stroke.universe, [0, 0, 1])
stroke["No"]=fuzz.trimf(stroke.universe, [0, 1, 1])

atherosclerosis["Yes"]=fuzz.trimf(atherosclerosis.universe, [0, 0, 1])
atherosclerosis["No"]=fuzz.trimf(atherosclerosis.universe, [0, 1, 1])

Obesity["Yes"]=fuzz.trimf(Obesity.universe, [0, 0, 1])
Obesity["No"]=fuzz.trimf(Obesity.universe, [0, 1, 1])

Heart_Disease["Yes"]=fuzz.trimf(Heart_Disease.universe, [0, 0, 1])
Heart_Disease["No"]=fuzz.trimf(Heart_Disease.universe, [0, 1, 1])

High_Blood_Pressure["Yes"]=fuzz.trimf(High_Blood_Pressure.universe, [0, 0, 1])
High_Blood_Pressure["No"]=fuzz.trimf(High_Blood_Pressure.universe, [0, 1, 1])

Type_II_Diabetes["Yes"]=fuzz.trimf(Type_II_Diabetes.universe, [0, 0, 1])
Type_II_Diabetes["No"]=fuzz.trimf(Type_II_Diabetes.universe, [0, 1, 1])

Chronic_Obstructive_Pulmonary_Disease["Yes"]=fuzz.trimf(Chronic_Obstructive_Pulmonary_Disease.universe, [0, 0, 1])
Chronic_Obstructive_Pulmonary_Disease["No"]=fuzz.trimf(Chronic_Obstructive_Pulmonary_Disease.universe, [0, 1, 1])

Chronic_Renal_Failure["Yes"]=fuzz.trimf(Chronic_Renal_Failure.universe, [0, 0, 1])
Chronic_Renal_Failure["No"]=fuzz.trimf(Chronic_Renal_Failure.universe, [0, 1, 1])

Osteoporosis["Yes"]=fuzz.trimf(Osteoporosis.universe, [0, 0, 1])
Osteoporosis["No"]=fuzz.trimf(Osteoporosis.universe, [0, 1, 1])

Swimmer_s_ear["Yes"]=fuzz.trimf(Swimmer_s_ear.universe, [0, 0, 1])
Swimmer_s_ear["No"]=fuzz.trimf(Swimmer_s_ear.universe, [0, 1, 1])


Nephritis["Yes"]=fuzz.trimf(Nephritis.universe, [0, 1, 1])
Nephritis["No"]=fuzz.trimf(Nephritis.universe, [0, 1, 1])




Eye_Pain["Yes"]=fuzz.trimf(Eye_Pain.universe, [0, 1, 1])
Eye_Pain["No"]=fuzz.trimf(Eye_Pain.universe, [0, 1, 1])

# %%
rule1 = ctrl.Rule(eight_hours_sleep['no'] & (headache['Sometimes'] | headache['Very Often']) & (depression['Sometimes'] | depression['Very Often']) & (stress_personal_life_work_life['Yes,I do'] | stress_personal_life_work_life['Sometimes']), mental_illness['Yes'])
rule2 = ctrl.Rule(eight_hours_sleep['yes'] , mental_illness['No'])


rule3 = ctrl.Rule(sit_straight['no'] & cushioned_chair_to_sit['no'] & (hours_sit['More than 10 hours'] | hours_sit['10 hours'] | hours_sit['9 hours']) &  (sit_in_front_of_computer['More than 12 hours'] | sit_in_front_of_computer['12 hours'] | sit_in_front_of_computer['8 hours']) , back_pain['Yes'])
rule4 = ctrl.Rule(sit_straight['yes'] , back_pain['No'])


rule5 = ctrl.Rule(headache['Very Often'] & (drinking_alchohol['Daily'] | drinking_alchohol['3-4 Days in a week']) , stroke['Yes'])
rule6 = ctrl.Rule(drinking_alchohol['Occasionally'] | drinking_alchohol['No, I do not smoke'], stroke['No'])

rule7 = ctrl.Rule( (smoking['Daily'] | smoking['3-4 Days in a week']) & stress_personal_life_work_life['Yes,I do'] & (junk_food['Daily'] | junk_food['3-4 days in a week']) , atherosclerosis['Yes'])
rule8 = ctrl.Rule(smoking['No, I do not smoke'] | smoking['Occasionally'], atherosclerosis['No'])

rule9 = ctrl.Rule((junk_food['Daily'] | junk_food['3-4 days in a week']) & walk_to_workplace['no'] & exercise['No,I do not'] , Obesity['Yes'])
rule10 = ctrl.Rule(walk_to_workplace['yes'] , Obesity['No'])


# def output5(hours_walk_in_a_day,walk_to_workplace,exercise,junk_food):
#   if(hours_walk_in_a_day==1 and walk_to_workplace==1 and exercise==1 and junk_food<=2):
#     d5.append('Obesity')
#   else :
#     d5.append('ok')
#   return d5
# rule1 = ctrl.Rule( (junk_food['Sometimes'] | junk_food['Very Often']) & walk_to_workplace['no'] &  exercise['No,I do not'], Obesity['Yes'])
# rule2 = ctrl.Rule(walk_to_workplace['yes'], Obesity['No'])
